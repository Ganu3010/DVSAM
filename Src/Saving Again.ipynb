# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:/My Docs/PICT CS/SE_21_22/PBL/DVSAM/Data/zomato_pune_V002.csv')
imp_columns = ['Restaurant_Name', 'Web_Link', 'Locality','Ratings_out_of_5', 'Cuisines', 'Charges_for_two']
df = df[imp_columns]

# %%
df['Charges_for_two'] = df['Charges_for_two'].replace('\D', '', regex=True)

# %%
ls1 = []
for i in df['Ratings_out_of_5']:
    try:
        ls1.append(float(i))
    except:
        ls1.append(0)

# %%
df['Ratings_out_of_5'] = ls1

# %%
df.to_csv('searchable.csv')

# %%
def search(user1):
    output = pd.DataFrame(columns =['Restaurant_Name', 'Web_Link', 'Locality','Ratings_out_of_5', 'Cuisines', 'Charges_for_two'])
    for i in user1.keys():
        output = output.append(df[df['Restaurant_Name'] == i])
    return output

# %%
df1 = pd.read_csv('combined.csv')

# %%
search({'Southern Spice': 3, 'Cafe Little Eggs': 4})
# Out:
#         Restaurant_Name                                           Web_Link  \
# 10962    Southern Spice  https://www.zomato.com/pune/southern-spice-dha...
# 1113   Cafe Little Eggs  https://www.zomato.com/pune/cafe-little-eggs-b...
#
#                Locality  Ratings_out_of_5              Cuisines  \
# 10962           Dhanori               2.8          South Indian
# 1113   Bund Garden Road               3.3  Fast Food, Beverages
#
#       Charges_for_two
# 10962             200
# 1113              300

# %%
x = {}
x[df['rest_name'][3]] = 3
x[df['rest_name'][10]] = 5
x[df['rest_name'][20]] = 1

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity  


class Predicting:
    def __init__(self):
        
        self.combine = pd.read_csv('G:/Projects/DVSAM/Src/combined.csv')
        self.combine = self.combine[['user_id', 'rest_name', 'rating']]
        self.pivot = self.combine.pivot_table(index=['user_id'], columns=['rest_name'], values='rating')
        self.pivot = self.pivot.fillna(0)
        self.pt_stand = self.pivot.apply(self.standardize)
        self.item_sim = cosine_similarity(self.pt_stand.T)
        self.item_sim = pd.DataFrame(self.item_sim, index=self.pt_stand.columns, columns=self.pt_stand.columns)

    def get_sim(self, rest, rating):
        sim_score = self.item_sim[rest]*(rating)
        sim_score = sim_score.sort_values(ascending = False).head(10)
        return sim_score
    def get_restaurant(self, user_dict):
        sim_rest = pd.DataFrame()
        # m = np.array(list(user_dict.values())).mean()
        for rest in user_dict:
            sim_rest = sim_rest.append(self.get_sim(rest=rest, rating = user_dict[rest]), ignore_index = True)
        
        sim_rest = sim_rest.sum().sort_values(ascending = False)
        sim_rest = dict(sim_rest.head(len(user_dict) + 10))
        r = {}
        for i in sim_rest:
            if not i in user_dict:
                r[i] = sim_rest[i]
        return r
    def standardize(self, row):
        if(row.max()-row.min() != 0):
            new_row = (row - row.mean())/(row.max() - row.min())
        else:
            new_row = row
        return new_row

# %%
pred = Predicting()

# %%
pred.get_restaurant(x)
# Out:
# {'The East': 8.673439729418643,
#  'Bangalore Iyangar Bakery': 8.673439729418643,
#  'Amrut Testy Paratha': 8.673439729418643,
#  'Shree Lakshmi Narayan Snacks & Pavbhaji Center': 8.673439729418643,
#  'Biryani Nawab': 8.673439729418643,
#  'Hooked': 7.844525252902029,
#  'Bombay Sandwich & Pizza': 7.760912485017053,
#  'Creative Food Catering': 7.760912485017053,
#  'Pik-A-Meal': 0.6734397294186232,
#  'Subcurry': 0.6734397294186232}

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('searchable.csv')

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
def search(search_var):
    output = pd.DataFrame(columns =['Restaurant_Name', 'Web_Link', 'Locality','Ratings_out_of_5', 'Cuisines', 'Charges_for_two'])
    for i in df.columns:
        for j in range(12188):
            if df[i][j] == search_var:
                output = output.append(df.loc[j])
    return output.drop_duplicates(subset = None, keep = 'first')

# %%
# Out:
#                   Restaurant_Name  \
# 1565   Govinda's The Higher Taste
# 2356             Fuzion - Novotel
# 4752                Granny's Bowl
# 4803                   Valley Bar
# 6764                Olde Bailey's
# 7135         The Daily-Cious Diet
# 11308         We-Can End Cravings
#
#                                                 Web_Link  \
# 1565   https://www.zomato.com/pune/govindas-the-highe...
# 2356   https://www.zomato.com/pune/fuzion-novotel-vim...
# 4752   https://www.zomato.com/pune/grannys-bowl-dhole...
# 4803   https://www.zomato.com/pune/valley-bar-old-mum...
# 6764   https://www.zomato.com/pune/olde-baileys-koreg...
# 7135   https://www.zomato.com/pune/the-daily-cious-di...
# 11308  https://www.zomato.com/pune/we-can-end-craving...
#
#                       Locality  Ratings_out_of_5     Cuisines  Charges_for_two
# 1565                    Katraj               3.8  Continental            500.0
# 2356               Viman Nagar               3.8  Continental            600.0
# 4752          Dhole Patil Road               3.7  Continental            300.0
# 4803   Old Mumbai-Pune Highway               3.6  Continental           1400.0
# 6764             Koregaon Park               3.8  Continental            900.0
# 7135             Koregaon Park               0.0  Continental            400.0
# 11308                  Wagholi               3.0  Continental              0.0

# %%
def search(search_var):
    search_var = search_var.split()
    output = pd.DataFrame(columns =['Restaurant_Name', 'Web_Link', 'Locality','Ratings_out_of_5', 'Cuisines', 'Charges_for_two'])
    for i in df.columns:
        for j in range(12188):
            for sv in search_var:
                if df[i][j] == sv:
                    output = output.append(df.loc[j])
    return output.drop_duplicates(subset = None, keep = 'first')

# %%
search('North Indian Hinjawadi')
# Out:
#                  Restaurant_Name  \
# 0      AB's - Absolute Barbecues
# 3                    I Amsterdam
# 7                         BeHive
# 21             Tarsh Gastronomia
# 24                        Publiq
# ...                          ...
# 12002                 Kebab King
# 12010                      Gusto
# 12040     Old City Biryani House
# 12129           Royal Hill Dairy
# 12184             Nil Food Point
#
#                                                 Web_Link   Locality  \
# 0      https://www.zomato.com/pune/abs-absolute-barbe...  Hinjawadi
# 3      https://www.zomato.com/pune/i-amsterdam-hinjawadi  Hinjawadi
# 7           https://www.zomato.com/pune/behive-hinjawadi  Hinjawadi
# 21     https://www.zomato.com/pune/tarsh-gastronomia-...  Hinjawadi
# 24          https://www.zomato.com/pune/publiq-hinjawadi  Hinjawadi
# ...                                                  ...        ...
# 12002   https://www.zomato.com/pune/kebab-king-hinjawadi  Hinjawadi
# 12010        https://www.zomato.com/pune/gusto-hinjawadi  Hinjawadi
# 12040  https://www.zomato.com/pune/old-city-biryani-h...  Hinjawadi
# 12129  https://www.zomato.com/pune/royal-hill-dairy-h...  Hinjawadi
# 12184  https://www.zomato.com/pune/nil-food-point-hin...  Hinjawadi
#
#        Ratings_out_of_5                                           Cuisines  \
# 0                   4.9                 Continental, North Indian, Chinese
# 3                   4.3            Asian, European, Modern Indian, Italian
# 7                   4.0                 North Indian, Chinese, Continental
# 21                  4.4  North Indian, Italian, Asian, Mediterranean, C...
# 24                  4.0             Bar Food, Asian, North Indian, Italian
# ...                 ...                                                ...
# 12002               3.5                       North Indian, Kebab, Chinese
# 12010               0.0                 North Indian, Chinese, Continental
# 12040               3.7                                Hyderabadi, Biryani
# 12129               0.0                                          Beverages
# 12184               0.0                                            Chinese
#
#        Charges_for_two
# 0               1400.0
# 3               1400.0
# 7               1400.0
# 21              1500.0
# 24              1600.0
# ...                ...
# 12002            700.0
# 12010            700.0
# 12040            650.0
# 12129            300.0
# 12184              0.0
#
# [479 rows x 6 columns]
